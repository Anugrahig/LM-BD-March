# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# x=area
# y=price

# %%
x=[2600,3000,3200,3600,4000]
y=[5500000,5800000,6100000,6800000,7200000]

# %%
sns.scatterplot(x=x,y=y)
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Area VS Price")
plt.plot()
# Out:
# []

# %%
from sklearn.linear_model
