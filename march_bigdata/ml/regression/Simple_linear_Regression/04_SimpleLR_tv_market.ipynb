# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../../Bigdata Files/tvmarketing.csv")
df
# Out:
#         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# TV       0
# Sales    0
# dtype: int64

# %%
X=df.drop("Sales",axis=1).values

# %%
y=df["Sales"].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
y_pred
# Out:
# array([14.81785392, 16.30754437, 20.83230507,  7.78243112, 17.46309864,
#        10.72468577, 17.30067133,  9.55984994, 17.56055502, 15.36546598,
#         8.7013056 ,  9.84757831, 18.12208943,  7.49006196, 13.71334823,
#        15.13806775,  7.57823679, 16.40964153, 10.73396733, 18.25667206,
#        17.89005042, 10.38590882,  9.00295631, 18.88317738, 10.44159818,
#         9.72227724, 17.14752559, 13.70406667, 11.28622018,  7.62928537,
#        16.5117387 , 10.45087974, 16.46997167,  8.02375169, 20.26612989,
#        18.2937983 ,  9.48095667, 19.94127527, 12.67845424,  8.51567439,
#        12.62276488, 15.45364081,  9.2396361 , 10.1306659 , 17.63480751,
#         9.01223787, 10.51585066, 14.07532908, 12.09371593, 10.78037513,
#        10.86854996, 15.05453371,  7.64320771,  7.60144069, 10.78501591,
#        13.24462943, 10.64579251, 20.68380011,  8.14905275, 16.40964153])

# %%
df_error=pd.DataFrame({"Actual val":y_test,"Pred val":y_pred,"Error":y_test-y_pred})
df_error
# Out:
#     Actual val   Pred val     Error
# 0         16.9  14.817854  2.082146
# 1         22.4  16.307544  6.092456
# 2         21.4  20.832305  0.567695
# 3          7.3   7.782431 -0.482431
# 4         24.7  17.463099  7.236901
# 5         12.6  10.724686  1.875314
# 6         22.3  17.300671  4.999329
# 7          8.4   9.559850 -1.159850
# 8         11.5  17.560555 -6.060555
# 9         14.9  15.365466 -0.465466
# 10         9.5   8.701306  0.798694
# 11         8.7   9.847578 -1.147578
# 12        11.9  18.122089 -6.222089
# 13         5.3   7.490062 -2.190062
# 14        10.3  13.713348 -3.413348
# 15        11.7  15.138068 -3.438068
# 16         5.5   7.578237 -2.078237
# 17        16.6  16.409642  0.190358
# 18        11.3  10.733967  0.566033
# 19        18.9  18.256672  0.643328
# 20        19.7  17.890050  1.809950
# 21        12.5  10.385909  2.114091
# 22        10.9   9.002956  1.897044
# 23        22.2  18.883177  3.316823
# 24         9.3  10.441598 -1.141598
# 25         8.1   9.722277 -1.622277
# 26        21.7  17.147526  4.552474
# 27        13.4  13.704067 -0.304067
# 28        10.6  11.286220 -0.686220
# 29         5.7   7.629285 -1.929285
# 30        10.6  16.511739 -5.911739
# 31        11.3  10.450880  0.849120
# 32        23.7  16.469972  7.230028
# 33         8.7   8.023752  0.676248
# 34        16.1  20.266130 -4.166130
# 35        20.7  18.293798  2.406202
# 36        11.6   9.480957  2.119043
# 37        20.8  19.941275  0.858725
# 38        11.9  12.678454 -0.778454
# 39         6.9   8.515674 -1.615674
# 40        11.0  12.622765 -1.622765
# 41        12.8  15.453641 -2.653641
# 42        10.1   9.239636  0.860364
# 43         9.7  10.130666 -0.430666
# 44        11.6  17.634808 -6.034808
# 45         7.6   9.012238 -1.412238
# 46        10.5  10.515851 -0.015851
# 47        14.6  14.075329  0.524671
# 48        10.4  12.093716 -1.693716
# 49        12.0  10.780375  1.219625
# 50        14.6  10.868550  3.731450
# 51        11.7  15.054534 -3.354534
# 52         7.2   7.643208 -0.443208
# 53         6.6   7.601441 -1.001441
# 54         9.4  10.785016 -1.385016
# 55        11.0  13.244629 -2.244629
# 56        10.9  10.645793  0.254207
# 57        25.4  20.683800  4.716200
# 58         7.6   8.149053 -0.549053
# 59        11.7  16.409642 -4.709642

# %%
plt.scatter(X,y)
plt.plot(X_test,y_pred)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 2.2758809050205118

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 8.970991242413616

# %%
print("MAPE",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# MAPE 0.18069079361253765

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 2.995161304907236
