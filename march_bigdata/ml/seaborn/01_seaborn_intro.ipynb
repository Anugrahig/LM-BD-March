# %% [markdown]
# # Seaborn

# %% [markdown]
# **Categorical : Countplot,boxplot,Violinplot,Strip plot,Swarm plot <br>
# Distribution plot : Pairplot,distplot, joint plot <br>
# Matrix : heat map, cluster map**
# <br>
# Categorical (Yes/No)

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# inbuilt dataset

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=pd.read_csv("../../Bigdata Files/tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# count plot : univarient
sns.countplot(x="smoker",data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="smoker",data=df,hue="sex")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
# time = count
sns.countplot(x="time",data=df,hue="day")
# Out:
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.countplot(x="smoker",data=df,hue="sex",palette="PuBuGn")
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="smoker",data=df,hue="sex",palette="pastel")
# pastel
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# ### barplot

# %%
sns.barplot(x="day",y="tip",data=df,palette="flare")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x="sex",y="tip",data=df,palette="Spectral")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x="day",y="tip",hue="sex",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
columns=['total_bill', 'sex', 'smoker', 'day', 'time', 'size']
# sns.barplot(x=tip,y=,data=df)
# for i in columns:
#     sns.barplot(x
="tip",y=i,data=df)

# %%
sns.barplot(x="tip",y="total_bill",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='total_bill'>

# %%
sns.barplot(x="tip",y="sex",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='sex'>

# %%
sns.barplot(x="tip",y="smoker",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='smoker'>

# %%
sns.barplot(x="tip",y="day",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.barplot(x="tip",y="time",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='time'>

# %%
sns.barplot(x="tip",y="size",data=df,palette="pastel6")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='size'>

# %%
# time : dinner
# day : sunday
# smoker = yes & no
# tip : male
