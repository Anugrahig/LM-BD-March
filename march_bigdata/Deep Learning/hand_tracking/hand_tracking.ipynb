# %%
import mediapipe as mp

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread("./data/hand1.jpg")

# %%
plt.imshow(img)

# %%
rgb_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_img)

# %%
mp_hands=mp.solutions.hands
mp_hands
# Out:
# <module 'mediapipe.python.solutions.hands' from '/home/anugrah/anaconda3/lib/python3.10/site-packages/mediapipe/python/solutions/hands.py'>

# %%
# static mode: img/video (by default False,means video)
# max no. of hands : 2
# model complexity

hands=mp_hands.Hands(static_image_mode=True,max_num_hands=2,min_detection_confidence=0.3)
hands
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
mp_drawings=mp.solutions.drawing_utils

# %%
mp_drawings
# Out:
# <module 'mediapipe.python.solutions.drawing_utils' from '/home/anugrah/anaconda3/lib/python3.10/site-packages/mediapipe/python/solutions/drawing_utils.py'>

# %%
results=hands.process(rgb_img)

if results.multi_hand_landmarks:
  # we need to group left and right groups
  for hand_no,hand_landmarks in enumerate(results.multi_hand_landmarks):
    # drawing
    mp_drawings.draw_landmarks(
      image=rgb_img,
      landmark_list=hand_landmarks,
      connections = mp_hands.HAND_CONNECTIONS
    )
    # connecting line is mp_hands.HAND_CONNECTIONS
    plt.imshow(rgb_img)
